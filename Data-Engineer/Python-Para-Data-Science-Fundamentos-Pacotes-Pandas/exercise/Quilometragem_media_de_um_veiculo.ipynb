# %% [markdown]
# ## Quilometragem média de um veículo
#
# Nosso projeto é o cálculo da quilometragem média que um veículo rodou por ano. Não existe uma função pronta para o cálculo desta estatística em Python, e por isso precisamos escrever uma função que obtenha este valor.
#
# Considere o conjunto de informações abaixo para responder o problema:
#
# ![image.png](attachment:image.png)
#
#
# dados = {
#     'Crossfox': {'km': 35000, 'ano': 2005},
#     'DS5': {'km': 17000, 'ano': 2015},
#     'Fusca': {'km': 130000, 'ano': 1979},
#     'Jetta': {'km': 56000, 'ano': 2011},
#     'Passat': {'km': 62000, 'ano': 1999}
# }
#
# A estrutura a seguir é a definição de uma função que obtém e imprime a quilometragem média anual de cada veículo em um dicionário com a estrutura do dicionário `dados` acima:
#
#     def km_media(dataset, ano_atual):
#         for item in _______________:
#             result = _____________ / (ano_atual - ____________)
#             print(result)
#
#     km_media(dados, 2019)
#
#     2500.0
#     4250.0
#     3250.0
#     7000.0
#     3100.0
#
#
# Assinale a alternativa que completa corretamente as lacunas da nossa função

# %%
dados = {
    'Crossfox': {'km': 35000, 'ano': 2005}, 
    'DS5': {'km': 17000, 'ano': 2015}, 
    'Fusca': {'km': 130000, 'ano': 1979}, 
    'Jetta': {'km': 56000, 'ano': 2011}, 
    'Passat': {'km': 62000, 'ano': 1999}
}

dados
# Out:
# {'Crossfox': {'km': 35000, 'ano': 2005},
#  'DS5': {'km': 17000, 'ano': 2015},
#  'Fusca': {'km': 130000, 'ano': 1979},
#  'Jetta': {'km': 56000, 'ano': 2011},
#  'Passat': {'km': 62000, 'ano': 1999}}

# %%
def km_media(dataset, ano_atual):
    for item in dataset.items():
        result = item[1]['km']  / (ano_atual - item[1]['ano'])
        print(result)

# %%
km_media(dados, 2019)
# Out:
# 2500.0
# 4250.0
# 3250.0
# 7000.0
# 3100.0
